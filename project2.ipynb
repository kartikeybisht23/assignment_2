# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle
# %matplotlib inline

# %%
dataset=pd.read_csv(r'C:\Users\Lenovo\Desktop\Mechademy\Expander_data.csv')

# %%
dataset
# Out:
#               Timestamp  Suction Pressure (psig)  Suction Temperature (F)  \
# 0        1/4/2020 21:20               596.100853              -229.436683
# 1        1/4/2020 21:20               596.838217              -230.453708
# 2        1/4/2020 21:20               596.468895              -229.545356
# 3        1/4/2020 21:20               603.568271              -230.309438
# 4        1/4/2020 21:21               595.407372              -229.767969
# 5        1/4/2020 21:21               594.415722              -229.595078
# 6        1/4/2020 21:21               597.170202              -230.133506
# 7        1/4/2020 21:21               603.331813              -229.551912
# 8        1/4/2020 21:22               595.013360              -229.575425
# 9        1/4/2020 21:22               598.340373              -229.808081
# 10       1/4/2020 21:22               604.875850              -230.077084
# 11       1/4/2020 21:22               597.126396              -229.536504
# ...

# %%
independent_val=dataset.iloc[:,[1,2,3,4,5,7]].values
dependent_val=dataset.iloc[:,6]
# Out:
# (296450,)

# %%
from sklearn.model_selection import train_test_split

# %%
independent_val_train,independent_val_test,dependent_val_train,dependent_val_test=train_test_split(independent_val,dependent_val,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(independent_val_train,dependent_val_train)
pickle.dump(model, open(r'C:\Users\Lenovo\Desktop\Mechademy\assignment_2.pickle', 'wb'))
loaded_model=pickle.load(open(r'C:\Users\Lenovo\Desktop\Mechademy\assignment_2.pickle', 'rb'))

# %%
loaded_model.predict(independent_val_test)
# Out:
# array([222.72814225,  83.96880061, 176.73937796, ..., 155.73502175,
#        155.11487864, 184.38247478])

# %%
dependent_val_test
# Out:
# 274942    223.476846
# 49603      80.235425
# 82487     177.581833
# 61469      86.535143
# 266616    215.612215
# 195029    153.183302
# 293957    219.789844
# 120245    237.248570
# 125900    227.508133
# 225940    131.544095
# 39446     121.269557
# 215677    132.831347
# 281581    227.698178
# 23581     303.962946
# 21738     300.067930
# 53985     101.354226
# 58481     101.825071
# 156600    205.875116
# 8320      154.186767
# 150414    195.701663
# 73227     151.757001
# 75248     172.635288
# 185170    158.154408
# 232998    143.509228
# 35653     142.168187
# 79306     179.478100
# 220790    141.469887
# 139475    236.415265
# 177838    150.210326
# 231868    144.745186
#              ...
# 20436     318.486713
# 272808    216.239266
# 68676     129.900930
# 282153    235.452387
# 104154    308.091169
# 42103     129.222926
# 103345    305.436851
# 18716     264.293470
# 40214     145.068445
# 132316    240.587698
# 227903    136.889162
# 131121    232.415390
# ...
